# %%
# Adapted from MYONN (Rashid 2016, 2024) by Hilary Abraham, 2024, for Science World BC
# python notebook for Make Your Own Neural Network
# code for a 3-layer neural network, and code for learning the MNIST dataset
# (c) Tariq Rashid, 2016
# license is GPLv2

# %%
# Add this to the neural network class definition


      
    # load neural network weights 
    def load(self):
        self.wih = numpy.load('ADD .npy wih FILE LOCATION HERE')
        self.who = numpy.load('ADD .npy who FILE LOCATION HERE')
        pass

# %%
# Add this cell IN LIEU OF training cell



# load previous weights instead of training anew
n.load()
